# %% [markdown]
# Shopping Cart and Product
# Operator System
# Problem Statement
# An online store wants to create a simple system for managing products and shopping carts.
# Each product should have a name, price, and available quantity. The store wants product
# objects to display meaningful information when printed. It also wants operators such as +, -, *,
# and == to perform useful operations on product and cart objects.
# A shopping cart should also be callable like a function so that calling the cart object returns the
# total amount payable.
# The program should provide or ask the user for:
# First product
# ● Product name: "Laptop"
# ● Unit price: 450000
# ● Available quantity: 10
# Second product
# ● Product name: "Laptop"
# ● Unit price: 450000
# ● Available quantity: 4
# Your program should use:
# Magic methods
# ● __str__() to return a user-friendly description of a product.
# ● __len__() to return the number of products stored inside a shopping cart.
# ● __call__() to make a shopping cart object callable and return the total price of all
# items in the cart.
# Operator overloading
#
# ● __add__() to add the quantities of two products with the same name and return a new
# Product object.
# ● __sub__() to subtract the quantity of one product from another and return a new
# Product object.
# ● __mul__() to calculate the total cost of purchasing a specified number of units of a
# product.
# ● __eq__() to compare two products using their names and unit prices.
# The program should:
# 1. Define a Product class with:
# ○ name
# ○ price
# ○ quantity
# 2. Define __str__() so that printing a product displays its name, price, and quantity.
# 3.Overload the + operator to combine the quantities of two matching products.
# 4. Overload the - operator to subtract one product quantity from another.
# 5. Prevent the result of subtraction from becoming negative.
# 6. Overload the * operator so that multiplying a product by a number returns the total
# purchase cost.
# 7. Overload the == operator so that two products are equal when they have the same
# name and unit price.
# 8. Define a ShoppingCart class that stores products in a list.
# 9. Define an add_product()0 method for adding products to the cart.
# 10. Use __len__() to return the number of product objects in the cart.
# 11. Use __call__() to return the total value of every product in the cart, using each
# product's price and quantity.
# 12. Create the two sample products and test all the required operations.

# %%
# ==========================================
# CREATING THE TWO PRODUCTS
# ==========================================

# First product
product1 = Product("Laptop", 450000, 10)

# Second product
product2 = Product("Laptop", 450000, 4)


# ==========================================
# TESTING __str__()
# ==========================================

print(f"Product 1: {product1}")
print(f"Product 2: {product2}")


# ==========================================
# TESTING __add__()
# ==========================================

combined_product = product1 + product2

print("\nCombined Product:")
print(combined_product)


# ==========================================
# TESTING __sub__()
# ==========================================

remaining_product = product1 - product2

print("\nRemaining Product:")
print(remaining_product)


# ==========================================
# TESTING __mul__()
# ==========================================

cost = product1 * 3

print(f"\nCost of 3 Laptops: ₦{cost:,.2f}")


# ==========================================
# TESTING __eq__()
# ==========================================

print(f"Are the products equal? {product1 == product2}")


# ==========================================
# CREATING THE SHOPPING CART
# ==========================================

cart = ShoppingCart()


# Add both products to the cart
cart.add_product(product1)
cart.add_product(product2)


# ==========================================
# TESTING __len__()
# ==========================================

print(f"Number of products in cart: {len(cart)}")


# ==========================================
# TESTING __call__()
# ==========================================

print(f"Total Cart Value: ₦{cart():,.2f}")
# Out:
# Product 1: Laptop | Price: ₦450,000.00 | Quantity: 10
# Product 2: Laptop | Price: ₦450,000.00 | Quantity: 4
#
# Combined Product:
# Laptop | Price: ₦450,000.00 | Quantity: 14
#
# Remaining Product:
# Laptop | Price: ₦450,000.00 | Quantity: 6
#
# Cost of 3 Laptops: ₦1,350,000.00
# Are the products equal? True
# Number of products in cart: 2
# Total Cart Value: ₦6,300,000.00
